# %% [markdown]
# # Datasets Cleaning

# %% [markdown]
# ## Groceries Dataset Cleaning

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Groceries.csv')
df.head()
# Out:
#    Unnamed: 0  pulses_1kg  flour_10kg  rice_5kg  oil_1ltr  soap  \
# 0           0         117         389       606       306    68
# 1           1         159         482       493       283    63
# 2           2          92         424       535       395    38
# 3           3         170         473       628       234    38
# 4           4          80         504       713       391    44
#
#    amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0         2194341             10              8                0  ...
# 1         8639411              6              7                1  ...
# 2         7205196             13              5                0  ...
# 3         4041602              7              6                1  ...
# 4         9191103              6              5                1  ...
#
#    no_of_units_sold_per_day_of_pulses  no_of_units_sold_per_day_of_flour  \
# 0                                   7                                 19
# 1                                   8                                  7
# 2                                  10                                  6
# 3                                  12                                 16
# 4                                   9                                  5
#
#    no_of_units_sold_per_day_of_rice  no_of_units_sold_per_day_of_oil  \
# 0                                12                                8
# 1                                 8                                4
# 2                                10                                8
# 3                                19                                8
# 4                                11                               11
#
#    no_of_units_sold_per_day_of_soap  profit_percentage_last_year  \
# 0                                36                           34
# 1                                31                            1
# 2                                16                           25
# 3                                21                           46
# 4                                31                           28
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  8               0        0                       0
# 1                  3               0        0                       1
# 2                 10               1        1                       0
# 3                 10               1        1                       1
# 4                  8               1        0                       1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Grocery Commodities Revenue

# %%
pulses_revenue = []
for i in range(0, 1000):
    pulses_revenue.append((df['pulses_1kg'].loc[i])*(df['no_of_units_sold_per_day_of_pulses'].loc[i])*365)

# %%
flour_revenue = []
for i in range(0, 1000):
    flour_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_flour'].loc[i])*365)

# %%
rice_revenue = []
for i in range(0, 1000):
    rice_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_rice'].loc[i])*365)

# %%
oil_revenue = []
for i in range(0, 1000):
    oil_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_oil'].loc[i])*365)

# %%
soap_revenue = []
for i in range(0, 1000):
    soap_revenue.append((df['flour_10kg'].loc[i])*(df['no_of_units_sold_per_day_of_soap'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Grocery Commodities

# %%
total_revenue = []
for i in range(0, 1000):
    total_revenue.append(pulses_revenue[i] + flour_revenue[i] + rice_revenue[i] + oil_revenue[i] + soap_revenue[i])

# %%
df['Total_Revenue'] = total_revenue
df
# Out:
#      Unnamed: 0  pulses_1kg  flour_10kg  rice_5kg  oil_1ltr  soap  \
# 0             0         117         389       606       306    68
# 1             1         159         482       493       283    63
# 2             2          92         424       535       395    38
# 3             3         170         473       628       234    38
# 4             4          80         504       713       391    44
# ..          ...         ...         ...       ...       ...   ...
# 995         995         136         383       662       393    56
# 996         996         124         543       675       357    67
# 997         997         165         407       429       266    72
# 998         998         190         502       418       397    22
# 999         999         139         479       531       333    43
#
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0           2194341             10              8                0  ...
# 1           8639411              6              7                1  ...
# 2           7205196             13              5                0  ...
# 3           4041602              7              6                1  ...
# 4           9191103              6              5                1  ...
# ..              ...            ...            ...              ...  ...
# 995         2596503             12              8                0  ...
# 996         3201051             13              3                0  ...
# 997         2737139              6              3                1  ...
# 998         6998563             14              5                0  ...
# 999         1169903              9              1                1  ...
#
#      no_of_units_sold_per_day_of_flour  no_of_units_sold_per_day_of_rice  \
# 0                                   19                                12
# 1                                    7                                 8
# 2                                    6                                10
# 3                                   16                                19
# 4                                    5                                11
# ..                                 ...                               ...
# 995                                 18                                14
# 996                                 15                                 5
# 997                                  7                                13
# 998                                  7                                11
# 999                                 16                                 5
#
#      no_of_units_sold_per_day_of_oil  no_of_units_sold_per_day_of_soap  \
# 0                                  8                                36
# 1                                  4                                31
# 2                                  8                                16
# 3                                  8                                21
# 4                                 11                                31
# ..                               ...                               ...
# 995                                7                                35
# 996                                3                                11
# 997                               10                                34
# 998                                5                                15
# 999                                6                                15
#
#      profit_percentage_last_year  competition_scale  sustainability  startup  \
# 0                             34                  8               0        0
# 1                              1                  3               0        0
# 2                             25                 10               1        1
# 3                             46                 10               1        1
# 4                             28                  8               1        0
# ..                           ...                ...             ...      ...
# 995                           26                  1               0        1
# 996                            7                  8               0        0
# 997                           15                  8               0        1
# 998                           22                  1               0        1
# 999                           41                  1               1        1
#
#      management_effectivity  Total_Revenue
# 0                         0       10947810
# 1                         1        9260780
# 2                         0        6526200
# 3                         1       11793880
# 4                         1       10932480
# ..                      ...            ...
# 995                       0       11039790
# 996                       0        7010190
# 997                       1        9808645
# 998                       1        7309490
# 999                       1        7748950
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df.drop(columns = ['Unnamed: 0','pulses_1kg', 'flour_10kg', 'rice_5kg', 'oil_1ltr', 'soap', 'no_of_units_sold_per_day_of_pulses', 'no_of_units_sold_per_day_of_flour', 'no_of_units_sold_per_day_of_rice', 'no_of_units_sold_per_day_of_oil', 'no_of_units_sold_per_day_of_soap'], inplace = True)
df
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0           2194341             10              8                0
# 1           8639411              6              7                1
# 2           7205196             13              5                0
# 3           4041602              7              6                1
# 4           9191103              6              5                1
# ..              ...            ...            ...              ...
# 995         2596503             12              8                0
# 996         3201051             13              3                0
# 997         2737139              6              3                1
# 998         6998563             14              5                0
# 999         1169903              9              1                1
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            866             2626136                           34
# 1            379             3530079                            1
# 2            607               13704                           25
# 3            631              760740                           46
# 4            549             4239769                           28
# ..           ...                 ...                          ...
# 995          584             1446763                           26
# 996          891             3515671                            7
# 997          498             3190966                           15
# 998          319             4324349                           22
# 999          500             3038933                           41
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    8               0        0                       0
# 1                    3               0        0                       1
# 2                   10               1        1                       0
# 3                   10               1        1                       1
# 4                    8               1        0                       1
# ..                 ...             ...      ...                     ...
# 995                  1               0        1                       0
# 996                  8               0        0                       0
# 997                  8               0        1                       1
# 998                  1               0        1                       1
# 999                  1               1        1                       1
#
#      Total_Revenue
# 0         10947810
# 1          9260780
# 2          6526200
# 3         11793880
# 4         10932480
# ..             ...
# 995       11039790
# 996        7010190
# 997        9808645
# 998        7309490
# 999        7748950
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Electronics Dataset Cleaning

# %%
df1 = pd.read_csv('Electronics.csv')
df1.head()
# Out:
#    Unnamed: 0  laptop  phone  tablet  television  gaming_console  \
# 0           0  132418  89006   35556      152056           34014
# 1           1  148670  73138   42669      139667           31219
# 2           2   80097  58530   40918       93328           35964
# 3           3  147145  69937   34825      124307           35933
# 4           4  137103  94860   37855      192082           28629
#
#    amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0          763678             10              8                0  ...
# 1         7672065              7              3                1  ...
# 2         6145468              6              6                0  ...
# 3         7285267              9              2                0  ...
# 4         5693485             13              2                0  ...
#
#    no_of_units_sold_per_day_of_laptop  no_of_units_sold_per_day_of_phone  \
# 0                                   3                                  2
# 1                                   9                                  5
# 2                                   9                                  2
# 3                                   9                                  4
# 4                                   1                                  2
#
#    no_of_units_sold_per_day_of_tablet  no_of_units_sold_per_day_of_television  \
# 0                                   3                                       2
# 1                                   2                                       2
# 2                                   4                                       4
# 3                                   3                                       2
# 4                                   1                                       3
#
#    no_of_units_sold_per_day_of_gaming_console  profit_percentage_last_year  \
# 0                                           2                           26
# 1                                           2                           38
# 2                                           1                           31
# 3                                           2                           32
# 4                                           2                           23
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  5               0        1                       1
# 1                  8               1        1                       1
# 2                 10               0        0                       0
# 3                  1               1        0                       1
# 4                  8               0        1                       1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Electronics Commodities Revenue

# %%
laptop_revenue = []
for i in range(0, 1000):
    laptop_revenue.append((df1['laptop'].loc[i])*(df1['no_of_units_sold_per_day_of_laptop'].loc[i])*365)

# %%
phone_revenue = []
for i in range(0, 1000):
    phone_revenue.append((df1['phone'].loc[i])*(df1['no_of_units_sold_per_day_of_phone'].loc[i])*365)

# %%
tablet_revenue = []
for i in range(0, 1000):
    tablet_revenue.append((df1['tablet'].loc[i])*(df1['no_of_units_sold_per_day_of_tablet'].loc[i])*365)

# %%
television_revenue = []
for i in range(0, 1000):
    television_revenue.append((df1['television'].loc[i])*(df1['no_of_units_sold_per_day_of_television'].loc[i])*365)

# %%
gaming_console_revenue = []
for i in range(0, 1000):
    gaming_console_revenue.append((df1['gaming_console'].loc[i])*(df1['no_of_units_sold_per_day_of_gaming_console'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Electronics Commodities

# %%
total_revenue1 = []
for i in range(0, 1000):
    total_revenue1.append(laptop_revenue[i] + phone_revenue[i] + tablet_revenue[i] + television_revenue[i] + gaming_console_revenue[i])

# %%
df1['Total_Revenue'] = total_revenue1
df1
# Out:
#      Unnamed: 0  laptop   phone  tablet  television  gaming_console  \
# 0             0  132418   89006   35556      152056           34014
# 1             1  148670   73138   42669      139667           31219
# 2             2   80097   58530   40918       93328           35964
# 3             3  147145   69937   34825      124307           35933
# 4             4  137103   94860   37855      192082           28629
# ..          ...     ...     ...     ...         ...             ...
# 995         995   68234   19516   31240       34180           33392
# 996         996   54163   30439   48413      163845           28260
# 997         997   56699  103125   33835       98858           32226
# 998         998  133914   13637   24386       94376           46307
# 999         999  129618   69038   31839       73522           29184
#
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  ...  \
# 0            763678             10              8                0  ...
# 1           7672065              7              3                1  ...
# 2           6145468              6              6                0  ...
# 3           7285267              9              2                0  ...
# 4           5693485             13              2                0  ...
# ..              ...            ...            ...              ...  ...
# 995         1766342              7              2                0  ...
# 996         7960820             13              6                0  ...
# 997         7218840              9              6                1  ...
# 998         2642612             11              3                0  ...
# 999         5014765              9              3                0  ...
#
#      no_of_units_sold_per_day_of_phone  no_of_units_sold_per_day_of_tablet  \
# 0                                    2                                   3
# 1                                    5                                   2
# 2                                    2                                   4
# 3                                    4                                   3
# 4                                    2                                   1
# ..                                 ...                                 ...
# 995                                  3                                   4
# 996                                  2                                   1
# 997                                  3                                   2
# 998                                  4                                   4
# 999                                  6                                   3
#
#      no_of_units_sold_per_day_of_television  \
# 0                                         2
# 1                                         2
# 2                                         4
# 3                                         2
# 4                                         3
# ..                                      ...
# 995                                       4
# 996                                       2
# 997                                       1
# 998                                       2
# 999                                       2
#
#      no_of_units_sold_per_day_of_gaming_console  profit_percentage_last_year  \
# 0                                             2                           26
# 1                                             2                           38
# 2                                             1                           31
# 3                                             2                           32
# 4                                             2                           23
# ..                                          ...                          ...
# 995                                           1                           27
# 996                                           1                            4
# 997                                           1                           34
# 998                                           2                           19
# 999                                           1                           15
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    5               0        1                       1
# 1                    8               1        1                       1
# 2                   10               0        0                       0
# 3                    1               1        0                       1
# 4                    8               0        1                       1
# ..                 ...             ...      ...                     ...
# 995                 10               0        1                       1
# 996                  2               0        0                       1
# 997                  2               1        1                       1
# 998                  9               0        0                       0
# 999                  8               0        1                       1
#
#      Total_Revenue
# 0        384737010
# 1        777752950
# 2        514971565
# 3        740587920
# 4        364336430
# ..             ...
# 995      178882120
# 996      209351955
# 997      268247625
# 998      500362440
# 999      676175275
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df1.drop(columns = ['Unnamed: 0','laptop', 'phone', 'tablet', 'television', 'gaming_console', 'no_of_units_sold_per_day_of_laptop', 'no_of_units_sold_per_day_of_phone', 'no_of_units_sold_per_day_of_tablet', 'no_of_units_sold_per_day_of_television', 'no_of_units_sold_per_day_of_gaming_console'], inplace = True)
df1
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0            763678             10              8                0
# 1           7672065              7              3                1
# 2           6145468              6              6                0
# 3           7285267              9              2                0
# 4           5693485             13              2                0
# ..              ...            ...            ...              ...
# 995         1766342              7              2                0
# 996         7960820             13              6                0
# 997         7218840              9              6                1
# 998         2642612             11              3                0
# 999         5014765              9              3                0
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            399             4475457                           26
# 1            524             4369060                           38
# 2            726             4592740                           31
# 3            486             4287880                           32
# 4            750             2706444                           23
# ..           ...                 ...                          ...
# 995          382             4527071                           27
# 996          451             4808313                            4
# 997          470              196367                           34
# 998          657              634498                           19
# 999          352              217563                           15
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    5               0        1                       1
# 1                    8               1        1                       1
# 2                   10               0        0                       0
# 3                    1               1        0                       1
# 4                    8               0        1                       1
# ..                 ...             ...      ...                     ...
# 995                 10               0        1                       1
# 996                  2               0        0                       1
# 997                  2               1        1                       1
# 998                  9               0        0                       0
# 999                  8               0        1                       1
#
#      Total_Revenue
# 0        384737010
# 1        777752950
# 2        514971565
# 3        740587920
# 4        364336430
# ..             ...
# 995      178882120
# 996      209351955
# 997      268247625
# 998      500362440
# 999      676175275
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Clothing Dataset Cleaning

# %%
df2 = pd.read_csv('Clothing.csv')
df2.head()
# Out:
#    Unnamed: 0  shirt  kurta   tops  shorts  jeans  amount_of_loan  \
# 0           0   1179   2734  10725    1702   1507         3824267
# 1           1   3569   2079  16574    2562   5481         4284919
# 2           2    997   2956  11429    1857   1326         4088261
# 3           3   2418   3090  11710    1791   1066         9322611
# 4           4   2836   4115   8948    1174   6232         9143030
#
#    interest_rate  time_to_repay  simple_interest  ...  \
# 0             13              6                0  ...
# 1             12              7                1  ...
# 2             14              1                0  ...
# 3             13              1                1  ...
# 4              9              3                0  ...
#
#    no_of_units_sold_per_day_of_shirt  no_of_units_sold_per_day_of_kurta  \
# 0                                  8                                  5
# 1                                 10                                  9
# 2                                 11                                  2
# 3                                 13                                  9
# 4                                  5                                  6
#
#    no_of_units_sold_per_day_of_tops  no_of_units_sold_per_day_of_shorts  \
# 0                                19                                   7
# 1                                19                                   8
# 2                                 9                                   6
# 3                                18                                  14
# 4                                17                                  12
#
#    no_of_units_sold_per_day_of_jeans  profit_percentage_last_year  \
# 0                                  9                           32
# 1                                  4                           26
# 2                                  7                           12
# 3                                  5                            9
# 4                                  4                           40
#
#    competition_scale  sustainability  startup  management_effectivity
# 0                  5               0        1                       0
# 1                  9               1        0                       1
# 2                  3               0        1                       0
# 3                  5               0        0                       1
# 4                  7               1        0                       0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Clothing Commodities Revenue

# %%
shirt_revenue = []
for i in range(0, 1000):
    shirt_revenue.append((df2['shirt'].loc[i])*(df2['no_of_units_sold_per_day_of_shirt'].loc[i])*365)

# %%
kurta_revenue = []
for i in range(0, 1000):
    kurta_revenue.append((df2['kurta'].loc[i])*(df2['no_of_units_sold_per_day_of_kurta'].loc[i])*365)

# %%
tops_revenue = []
for i in range(0, 1000):
    tops_revenue.append((df2['tops'].loc[i])*(df2['no_of_units_sold_per_day_of_tops'].loc[i])*365)

# %%
shorts_revenue = []
for i in range(0, 1000):
    shorts_revenue.append((df2['shorts'].loc[i])*(df2['no_of_units_sold_per_day_of_shorts'].loc[i])*365)

# %%
jeans_revenue = []
for i in range(0, 1000):
    jeans_revenue.append((df2['jeans'].loc[i])*(df2['no_of_units_sold_per_day_of_jeans'].loc[i])*365)

# %% [markdown]
# ### Total Revenue of Clothing Commodities

# %%
total_revenue2 = []
for i in range(0, 1000):
    total_revenue2.append(shirt_revenue[i] + kurta_revenue[i] + tops_revenue[i] + shorts_revenue[i] + jeans_revenue[i])

# %%
df2['Total_Revenue'] = total_revenue2
df2
# Out:
#      Unnamed: 0  shirt  kurta   tops  shorts  jeans  amount_of_loan  \
# 0             0   1179   2734  10725    1702   1507         3824267
# 1             1   3569   2079  16574    2562   5481         4284919
# 2             2    997   2956  11429    1857   1326         4088261
# 3             3   2418   3090  11710    1791   1066         9322611
# 4             4   2836   4115   8948    1174   6232         9143030
# ..          ...    ...    ...    ...     ...    ...             ...
# 995         995    712   6773  15844    2872   2524         9056824
# 996         996   3230   1130  12860     590   5466         7489406
# 997         997   3502   6165  19272     847   6171         4267190
# 998         998   2482   6630  16448    2527   6721         6169537
# 999         999   3461   1164   6372     692   3337         7321804
#
#      interest_rate  time_to_repay  simple_interest  ...  \
# 0               13              6                0  ...
# 1               12              7                1  ...
# 2               14              1                0  ...
# 3               13              1                1  ...
# 4                9              3                0  ...
# ..             ...            ...              ...  ...
# 995             12              2                0  ...
# 996             10              7                1  ...
# 997              7              8                1  ...
# 998             14              6                1  ...
# 999             10              8                0  ...
#
#      no_of_units_sold_per_day_of_kurta  no_of_units_sold_per_day_of_tops  \
# 0                                    5                                19
# 1                                    9                                19
# 2                                    2                                 9
# 3                                    9                                18
# 4                                    6                                17
# ..                                 ...                               ...
# 995                                  1                                12
# 996                                  3                                 9
# 997                                  9                                 9
# 998                                  5                                15
# 999                                  5                                 5
#
#      no_of_units_sold_per_day_of_shorts  no_of_units_sold_per_day_of_jeans  \
# 0                                     7                                  9
# 1                                     8                                  4
# 2                                     6                                  7
# 3                                    14                                  5
# 4                                    12                                  4
# ..                                  ...                                ...
# 995                                  13                                 10
# 996                                  11                                  7
# 997                                  11                                  5
# 998                                  14                                  9
# 999                                   4                                  9
#
#      profit_percentage_last_year  competition_scale  sustainability  startup  \
# 0                             32                  5               0        1
# 1                             26                  9               1        0
# 2                             12                  3               0        1
# 3                              9                  5               0        0
# 4                             40                  7               1        0
# ..                           ...                ...             ...      ...
# 995                           47                  6               1        0
# 996                            1                  8               1        1
# 997                           44                 10               1        0
# 998                           26                  6               1        1
# 999                           28                  1               0        0
#
#      management_effectivity  Total_Revenue
# 0                         0       92109210
# 1                         1      150280355
# 2                         0       51159860
# 3                         1      109656220
# 4                         0       83950730
# ..                      ...            ...
# 995                       0       97048025
# 996                       1       70427480
# 997                       0      116118545
# 998                       0      148015165
# 999                       0       29515360
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Drop irrelevant columns

# %%
df2.drop(columns = ['Unnamed: 0','shirt', 'kurta', 'tops', 'shorts', 'jeans', 'no_of_units_sold_per_day_of_shirt', 'no_of_units_sold_per_day_of_kurta', 'no_of_units_sold_per_day_of_tops', 'no_of_units_sold_per_day_of_shorts', 'no_of_units_sold_per_day_of_jeans'], inplace = True)
df2
# Out:
#      amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0           3824267             13              6                0
# 1           4284919             12              7                1
# 2           4088261             14              1                0
# 3           9322611             13              1                1
# 4           9143030              9              3                0
# ..              ...            ...            ...              ...
# 995         9056824             12              2                0
# 996         7489406             10              7                1
# 997         4267190              7              8                1
# 998         6169537             14              6                1
# 999         7321804             10              8                0
#
#      cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0            746             4906804                           32
# 1            546             2294871                           26
# 2            700             1024957                           12
# 3            866             3940023                            9
# 4            866              613760                           40
# ..           ...                 ...                          ...
# 995          729             3283416                           47
# 996          629              452729                            1
# 997          390             2039990                           44
# 998          605             2924053                           26
# 999          476             3412198                           28
#
#      competition_scale  sustainability  startup  management_effectivity  \
# 0                    5               0        1                       0
# 1                    9               1        0                       1
# 2                    3               0        1                       0
# 3                    5               0        0                       1
# 4                    7               1        0                       0
# ..                 ...             ...      ...                     ...
# 995                  6               1        0                       0
# 996                  8               1        1                       1
# 997                 10               1        0                       0
# 998                  6               1        1                       0
# 999                  1               0        0                       0
#
#      Total_Revenue
# 0         92109210
# 1        150280355
# 2         51159860
# 3        109656220
# 4         83950730
# ..             ...
# 995       97048025
# 996       70427480
# 997      116118545
# 998      148015165
# 999       29515360
#
# [1000 rows x 12 columns]

# %% [markdown]
# ## Combine all datasets

# %%
newdf = pd.concat([df, df1, df2], ignore_index = True)
newdf
# Out:
#       amount_of_loan  interest_rate  time_to_repay  simple_interest  \
# 0            2194341             10              8                0
# 1            8639411              6              7                1
# 2            7205196             13              5                0
# 3            4041602              7              6                1
# 4            9191103              6              5                1
# ...              ...            ...            ...              ...
# 2995         9056824             12              2                0
# 2996         7489406             10              7                1
# 2997         4267190              7              8                1
# 2998         6169537             14              6                1
# 2999         7321804             10              8                0
#
#       cibil_score  past_debt_to_repay  profit_percentage_last_year  \
# 0             866             2626136                           34
# 1             379             3530079                            1
# 2             607               13704                           25
# 3             631              760740                           46
# 4             549             4239769                           28
# ...           ...                 ...                          ...
# 2995          729             3283416                           47
# 2996          629              452729                            1
# 2997          390             2039990                           44
# 2998          605             2924053                           26
# 2999          476             3412198                           28
#
#       competition_scale  sustainability  startup  management_effectivity  \
# 0                     8               0        0                       0
# 1                     3               0        0                       1
# 2                    10               1        1                       0
# 3                    10               1        1                       1
# 4                     8               1        0                       1
# ...                 ...             ...      ...                     ...
# 2995                  6               1        0                       0
# 2996                  8               1        1                       1
# 2997                 10               1        0                       0
# 2998                  6               1        1                       0
# 2999                  1               0        0                       0
#
#       Total_Revenue
# 0          10947810
# 1           9260780
# 2           6526200
# 3          11793880
# 4          10932480
# ...             ...
# 2995       97048025
# 2996       70427480
# 2997      116118545
# 2998      148015165
# 2999       29515360
#
# [3000 rows x 12 columns]

# %%
newdf.to_csv('FinalDataset.csv')
